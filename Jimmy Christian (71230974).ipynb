# %%
file1 =  input("Masukkan nama file pertama: ")
file2 = input("Masukkan nama file kedua: ")

handle1 = open(file1)
handle2 = open(file2)
isi1 = ""
isi2 = ""
beda1 = ""
beda2 = ""
lebih = ""

for i in handle1:
    isi1 = isi1 + i
for j in handle2:
    isi2 = isi2 + j
baris1 = isi1.split("\n")
baris2 = isi2.split("\n")

if len(baris1) == len(baris2):
    for k in range (len((baris1))):
        if baris1[k] == baris2[k]:
            continue
        else:
            barisindeks1 = baris1[k].split(" ")
            barisindeks2 = baris2[k].split(" ")
            if len(barisindeks1) == len(barisindeks2):
                for l in range (len(barisindeks1)):
                    if barisindeks1[l] == barisindeks2[l]:
                        continue
                    else:
                        print (f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {barisindeks1[l]}\nFile ke-2: {barisindeks2[l]}")
            else:
                if len(barisindeks1) > len(barisindeks2):
                    for a in range (len(barisindeks2)):
                        if barisindeks1[a] == barisindeks2[a]:
                            continue
                        else:
                            beda1 = beda1 + " " + barisindeks1[a]
                            beda2 = beda2 + " " + barisindeks2[a]
                            for b in range (len(barisindeks2),len(barisindeks1)):
                                lebih = lebih + " " + barisindeks1[b]
                            hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                            print(hasil)
                            beda1 = ""
                            beda2 = ""
                            lebih = ""
                else:
                    for a in range (len(barisindeks1)):
                        if barisindeks1[a] == barisindeks2[a]:
                            continue
                        else:
                            beda1 = beda1 + " " + barisindeks1[a]
                            beda2 = beda2 + " " + barisindeks2[a]
                            for b in range (len(barisindeks1),len(barisindeks2)):
                                lebih = lebih + " " + barisindeks2[b]
                            hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                            print(hasil)
                            beda1 = ""
                            beda2 = ""
                            lebih = ""

else:
    if len(baris1) >= len(baris2):
        for k in range (len((baris2))):
            if baris1[k] == baris2[k]:
                continue
            else:
                barisindeks1 = baris1[k].split(" ")
                barisindeks2 = baris2[k].split(" ")
                if len(barisindeks1) == len(barisindeks2):
                    for l in range (len(barisindeks1)):
                        if barisindeks1[l] == barisindeks2[l]:
                            continue
                        else:
                            print (f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {barisindeks1[l]}\nFile ke-2: {barisindeks2[l]}")
                else:
                    if len(barisindeks1) > len(barisindeks2):
                        for a in range (len(barisindeks2)):
                            if barisindeks1[a] == barisindeks2[a]:
                                continue
                            else:
                                beda1 = beda1 + " " + barisindeks1[a]
                                beda2 = beda2 + " " + barisindeks2[a]
                                for b in range (len(barisindeks2),len(barisindeks1)):
                                    lebih = lebih + " " + barisindeks1[b]
                                hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                                print(hasil)
                                beda1 = ""
                                beda2 = ""
                                lebih = ""
                    else:
                        for a in range (len(barisindeks1)):
                            if barisindeks1[a] == barisindeks2[a]:
                                continue
                            else:
                                beda1 = beda1 + " " + barisindeks1[a]
                                beda2 = beda2 + " " + barisindeks2[a]
                                for b in range (len(barisindeks1),len(barisindeks2)):
                                    lebih = lebih + " " + barisindeks2[b]
                                hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                                print(hasil)
                                beda1 = ""
                                beda2 = ""
                                lebih = ""
        for l in range (len(baris2), len(baris1)):
            hasil = f"Perbedaan pada Baris ke-{l+1}\nFile ke-1: {baris1[l]}\nFile ke-2: "
            print(hasil)
    else:
        for k in range (len((baris1))):
            if baris1[k] == baris2[k]:
                continue
            else:
                barisindeks1 = baris1[k].split(" ")
                barisindeks2 = baris2[k].split(" ")
                if len(barisindeks1) == len(barisindeks2):
                    for l in range (len(barisindeks1)):
                        if barisindeks1[l] == barisindeks2[l]:
                            continue
                        else:
                            print (f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {barisindeks1[l]}\nFile ke-2: {barisindeks2[l]}")
                else:
                    if len(barisindeks1) > len(barisindeks2):
                        for a in range (len(barisindeks2)):
                            if barisindeks1[a] == barisindeks2[a]:
                                continue
                            else:
                                beda1 = beda1 + " " + barisindeks1[a]
                                beda2 = beda2 + " " + barisindeks2[a]
                                for b in range (len(barisindeks2),len(barisindeks1)):
                                    lebih = lebih + " " + barisindeks1[b]
                                hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                                print(hasil)
                                beda1 = ""
                                beda2 = ""
                                lebih = ""
                    else:
                        for a in range (len(barisindeks1)):
                            if barisindeks1[a] == barisindeks2[a]:
                                continue
                            else:
                                beda1 = beda1 + " " + barisindeks1[a]
                                beda2 = beda2 + " " + barisindeks2[a]
                                for b in range (len(barisindeks1),len(barisindeks2)):
                                    lebih = lebih + " " + barisindeks2[b]
                                hasil = f"Perbedaan pada Baris ke-{k+1}\nFile ke-1: {beda1.strip()}\nFile ke-2: {beda2.strip()}\nFile ke-1: {lebih.strip()}\nFile ke-2:"
                                print(hasil)
                                beda1 = ""
                                beda2 = ""
                                lebih = ""
        for l in range (len(baris1), len(baris2)):
            hasil = f"Perbedaan pada Baris ke-{l+1}\nFile ke-1: \nFile ke-2: {baris2[l]}"
            print(hasil)

# %%
handle = open("text soal.txt").readlines()
lower = ""
split = ""
soal = ""
kunci_jawaban = ""
lower_jawaban = ""
for i in range (len(handle)):
    split = handle[i].split("|| ")
    soal = soal + split[0] + "\n"
    kunci_jawaban = kunci_jawaban + split[1].lower()
for k in range (5):
    print (soal.split("\n")[k])
    jawaban = input("Jawab: ")
    lower_jawaban = jawaban.lower().strip()
    if lower_jawaban == kunci_jawaban.split("\n")[k]:
        print ("Jawaban benar!")
    else:
        print ("Jawaban salah!")

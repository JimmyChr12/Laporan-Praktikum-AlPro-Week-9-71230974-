# %%
filesatu =  input("Masukkan nama file pertama: ")
filedua = input("Masukkan nama file kedua: ")

handlesatu = open(filesatu)
handledua = open(filedua)
readsatu = handlesatu.readlines()
readdua = handledua.readlines()
splitsatu = ""
splitdua = ""
bedasatu = ""
bedadua = ""
lebih = ""

if len(readsatu) >= len(readdua):
    tinggisatu = len(readsatu)
    tinggidua = len(readdua)
else:
    tinggisatu = len(readdua)
    tinggidua = len(readsatu)

for i in range(tinggidua):
    splitsatu = readsatu[i].split()
    splitdua = readdua[i].split()
    if len(splitsatu) >= len(splitdua):
        lebarsatu = len(splitsatu)
        lebardua = len(splitdua)
    else:
        lebarsatu = len(splitdua)
        lebardua = len(splitsatu)
    
    if readsatu[i] == readdua[i]:
        continue
    else:
        for k in range (lebardua):
            if splitsatu[k] == splitdua[k]:
                continue
            else:
                bedasatu = bedasatu + " " + splitsatu[k]
                bedadua = bedadua + " " + splitdua[k]
    for j in range (lebardua,lebarsatu):
        lebih = lebih + " " + splitsatu[j] or splitdua[j]
    print(f"Perbedaan pada Baris ke-{i+1}\nFile ke-1:{bedasatu} " + lebih.strip() + f"\nFile ke-2: {bedadua.strip()}")
    bedasatu = ""
    bedadua = ""
    lebih = ""

tinggisatu = len(readsatu)
tinggidua = len(readdua)
if tinggisatu > tinggidua:
    for k in range (tinggidua+1, tinggisatu):
        splitsatu = readsatu[k].split()
        lebarsatu = len(splitsatu)
        lebardua = 0
        for j in range (lebardua,lebarsatu):
            lebih = lebih + " " + splitsatu[j]
    print(f"Perbedaan pada Baris ke-{k+1}\nFile ke-1:{lebih}\nFile ke-2: ")
    lebih = ""
else:
    for k in range (tinggisatu+1, tinggidua):
        splitdua = readdua[k].split()
        lebarsatu = 0
        lebardua = len(splitdua)
        for j in range (lebarsatu,lebardua):
            lebih = lebih + " " + splitdua[j]
    print(f"Perbedaan pada Baris ke-{k+1}\nFile ke-1:{lebih}\nFile ke-2: ")
    lebih = ""

# %%
handle = open("text soal.txt").readlines()
lower = ""
split = ""
soal = ""
kunci_jawaban = ""
lower_jawaban = ""
for i in range (len(handle)):
    split = handle[i].split("|| ")
    soal = soal + split[0] + "\n"
    kunci_jawaban = kunci_jawaban + split[1].lower()
for k in range (5):
    print (soal.split("\n")[k])
    jawaban = input("Jawab: ")
    lower_jawaban = jawaban.lower().strip()
    if lower_jawaban == kunci_jawaban.split("\n")[k]:
        print ("Jawaban benar!")
    else:
        print ("Jawaban salah!")
